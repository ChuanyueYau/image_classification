# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 8
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 8:
# Image - Min Value: 8 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return (x-0.)/(255.-0.)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    y = np.zeros((len(x),10))
    for i in range(len(x)):
        y[i,x[i]] = 1
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None] + list(image_shape), name = "x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None,n_classes], name = "y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = "keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    x_dimension = x_tensor.get_shape().as_list()
    dimension = list(conv_ksize + (x_dimension[-1],) + (conv_num_outputs,)) # (height, width, input_depth, output_depth)
    # initialize weights and bias
    weights = tf.Variable(tf.truncated_normal(dimension,0,0.1)) 
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    padding = 'SAME'
    
    conv_layer = tf.nn.conv2d(x_tensor, weights, list((1,)+conv_strides+(1,)), padding)
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    
    conv_layer = tf.nn.relu(conv_layer)
    
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=list((1,)+pool_ksize+(1,)),
        strides=list((1,)+pool_strides+(1,)),
        padding='SAME')
    
    return conv_layer
 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dimension = x_tensor.get_shape().as_list()    
    return tf.reshape(x_tensor,[-1,np.prod(dimension[1:])])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_dimension = x_tensor.get_shape().as_list()
    dimension = list( (x_dimension[-1],) + (num_outputs,))
    weight = tf.Variable(tf.truncated_normal(dimension,0,0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.nn.relu(tf.add(tf.matmul(x_tensor,weight), bias))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_dimension = x_tensor.get_shape().as_list()
    dimension = list( (x_dimension[-1],) + (num_outputs,))
    weight = tf.Variable(tf.truncated_normal(dimension,0,0.01))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.add(tf.matmul(x_tensor,weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    # model with one Convolutiion and Max_pool layers
    conv_pool_layer = conv2d_maxpool(x, conv_num_outputs=32, conv_ksize=(4,4), conv_strides=(1,1), pool_ksize=(8,8), pool_strides=(1,1))
    #conv_pool_layer = conv2d_maxpool(conv_pool_layer, conv_num_outputs=64, conv_ksize=(4,4), conv_strides=(1,1), pool_ksize=(2,2), pool_strides=(1,1))
    
    conv_pool_layer = tf.nn.dropout(conv_pool_layer, keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flatten_layer = flatten(conv_pool_layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    # two fully connected layers
    full_layer = fully_conn(flatten_layer,256)
    full_layer = fully_conn(full_layer,128)

    
    full_layer = tf.nn.dropout(full_layer, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(full_layer,10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x:feature_batch, y:label_batch, keep_prob:keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={x:feature_batch, y:label_batch, keep_prob:1.0})
    validation_acc = session.run(accuracy, feed_dict={x:valid_features, y:valid_labels, keep_prob:1.0})
    print('Loss:{:.4f} Validation_accuracy:{:.4f}'.format(loss,validation_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 80
batch_size = 512
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:2.1129 Validation_accuracy:0.2210
# Epoch  2, CIFAR-10 Batch 1:  Loss:1.8771 Validation_accuracy:0.3374
# Epoch  3, CIFAR-10 Batch 1:  Loss:1.7306 Validation_accuracy:0.3960
# Epoch  4, CIFAR-10 Batch 1:  Loss:1.5960 Validation_accuracy:0.4380
# Epoch  5, CIFAR-10 Batch 1:  Loss:1.5056 Validation_accuracy:0.4712
# Epoch  6, CIFAR-10 Batch 1:  Loss:1.4007 Validation_accuracy:0.4866
# Epoch  7, CIFAR-10 Batch 1:  Loss:1.3283 Validation_accuracy:0.5130
# Epoch  8, CIFAR-10 Batch 1:  Loss:1.2486 Validation_accuracy:0.5136
# Epoch  9, CIFAR-10 Batch 1:  Loss:1.1860 Validation_accuracy:0.5336
# Epoch 10, CIFAR-10 Batch 1:  Loss:1.1240 Validation_accuracy:0.5510
# Epoch 11, CIFAR-10 Batch 1:  Loss:1.0759 Validation_accuracy:0.5428
# Epoch 12, CIFAR-10 Batch 1:  Loss:1.0504 Validation_accuracy:0.5496
# Epoch 13, CIFAR-10 Batch 1:  Loss:0.9743 Validation_accuracy:0.5716
# Epoch 14, CIFAR-10 Batch 1:  Loss:0.9707 Validation_accuracy:0.5690
# Epoch 15, CIFAR-10 Batch 1:  Loss:0.9732 Validation_accuracy:0.5604
# Epoch 16, CIFAR-10 Batch 1:  Loss:0.8936 Validation_accuracy:0.5802
# Epoch 17, CIFAR-10 Batch 1:  Loss:0.8543 Validation_accuracy:0.5850
# Epoch 18, CIFAR-10 Batch 1:  Loss:0.8356 Validation_accuracy:0.5848
# Epoch 19, CIFAR-10 Batch 1:  Loss:0.7789 Validation_accuracy:0.5968
# Epoch 20, CIFAR-10 Batch 1:  Loss:0.8384 Validation_accuracy:0.5772
# Epoch 21, CIFAR-10 Batch 1:  Loss:0.7348 Validation_accuracy:0.5932
# Epoch 22, CIFAR-10 Batch 1:  Loss:0.7012 Validation_accuracy:0.6008
# Epoch 23, CIFAR-10 Batch 1:  Loss:0.6564 Validation_accuracy:0.6036
# Epoch 24, CIFAR-10 Batch 1:  Loss:0.6346 Validation_accuracy:0.6062
# Epoch 25, CIFAR-10 Batch 1:  Loss:0.6327 Validation_accuracy:0.6044
# Epoch 26, CIFAR-10 Batch 1:  Loss:0.6014 Validation_accuracy:0.6012
# Epoch 27, CIFAR-10 Batch 1:  Loss:0.5901 Validation_accuracy:0.6100
# Epoch 28, CIFAR-10 Batch 1:  Loss:0.5467 Validation_accuracy:0.6114
# Epoch 29, CIFAR-10 Batch 1:  Loss:0.5266 Validation_accuracy:0.6090
# Epoch 30, CIFAR-10 Batch 1:  Loss:0.5030 Validation_accuracy:0.6168
# Epoch 31, CIFAR-10 Batch 1:  Loss:0.4868 Validation_accuracy:0.6118
# Epoch 32, CIFAR-10 Batch 1:  Loss:0.4665 Validation_accuracy:0.6084
# Epoch 33, CIFAR-10 Batch 1:  Loss:0.4703 Validation_accuracy:0.6102
# Epoch 34, CIFAR-10 Batch 1:  Loss:0.4304 Validation_accuracy:0.6202
# Epoch 35, CIFAR-10 Batch 1:  Loss:0.4562 Validation_accuracy:0.6014
# Epoch 36, CIFAR-10 Batch 1:  Loss:0.4251 Validation_accuracy:0.6092
# Epoch 37, CIFAR-10 Batch 1:  Loss:0.3960 Validation_accuracy:0.6240
# Epoch 38, CIFAR-10 Batch 1:  Loss:0.3821 Validation_accuracy:0.6256
# Epoch 39, CIFAR-10 Batch 1:  Loss:0.4084 Validation_accuracy:0.6050
# Epoch 40, CIFAR-10 Batch 1:  Loss:0.3623 Validation_accuracy:0.6090
# Epoch 41, CIFAR-10 Batch 1:  Loss:0.3472 Validation_accuracy:0.6180
# Epoch 42, CIFAR-10 Batch 1:  Loss:0.3253 Validation_accuracy:0.6152
# Epoch 43, CIFAR-10 Batch 1:  Loss:0.3122 Validation_accuracy:0.6190
# Epoch 44, CIFAR-10 Batch 1:  Loss:0.3244 Validation_accuracy:0.6072
# Epoch 45, CIFAR-10 Batch 1:  Loss:0.3211 Validation_accuracy:0.6240
# Epoch 46, CIFAR-10 Batch 1:  Loss:0.3218 Validation_accuracy:0.6178
# Epoch 47, CIFAR-10 Batch 1:  Loss:0.2642 Validation_accuracy:0.6340
# Epoch 48, CIFAR-10 Batch 1:  Loss:0.2373 Validation_accuracy:0.6288
# Epoch 49, CIFAR-10 Batch 1:  Loss:0.2331 Validation_accuracy:0.6338
# Epoch 50, CIFAR-10 Batch 1:  Loss:0.2369 Validation_accuracy:0.6210
# Epoch 51, CIFAR-10 Batch 1:  Loss:0.2471 Validation_accuracy:0.6208
# Epoch 52, CIFAR-10 Batch 1:  Loss:0.1972 Validation_accuracy:0.6314
# Epoch 53, CIFAR-10 Batch 1:  Loss:0.1817 Validation_accuracy:0.6342
# Epoch 54, CIFAR-10 Batch 1:  Loss:0.1684 Validation_accuracy:0.6230
# Epoch 55, CIFAR-10 Batch 1:  Loss:0.1686 Validation_accuracy:0.6308
# Epoch 56, CIFAR-10 Batch 1:  Loss:0.1647 Validation_accuracy:0.6258
# Epoch 57, CIFAR-10 Batch 1:  Loss:0.1426 Validation_accuracy:0.6324
# Epoch 58, CIFAR-10 Batch 1:  Loss:0.1303 Validation_accuracy:0.6346
# Epoch 59, CIFAR-10 Batch 1:  Loss:0.1363 Validation_accuracy:0.6280
# Epoch 60, CIFAR-10 Batch 1:  Loss:0.1422 Validation_accuracy:0.6264
# Epoch 61, CIFAR-10 Batch 1:  Loss:0.1192 Validation_accuracy:0.6314
# Epoch 62, CIFAR-10 Batch 1:  Loss:0.1161 Validation_accuracy:0.6262
# Epoch 63, CIFAR-10 Batch 1:  Loss:0.1132 Validation_accuracy:0.6268
# Epoch 64, CIFAR-10 Batch 1:  Loss:0.1206 Validation_accuracy:0.6182
# Epoch 65, CIFAR-10 Batch 1:  Loss:0.1078 Validation_accuracy:0.6240
# Epoch 66, CIFAR-10 Batch 1:  Loss:0.1025 Validation_accuracy:0.6186
# Epoch 67, CIFAR-10 Batch 1:  Loss:0.0957 Validation_accuracy:0.6216
# Epoch 68, CIFAR-10 Batch 1:  Loss:0.0857 Validation_accuracy:0.6250
# Epoch 69, CIFAR-10 Batch 1:  Loss:0.0758 Validation_accuracy:0.6308
# Epoch 70, CIFAR-10 Batch 1:  Loss:0.0733 Validation_accuracy:0.6340
# Epoch 71, CIFAR-10 Batch 1:  Loss:0.0663 Validation_accuracy:0.6358
# Epoch 72, CIFAR-10 Batch 1:  Loss:0.0735 Validation_accuracy:0.6252
# Epoch 73, CIFAR-10 Batch 1:  Loss:0.0713 Validation_accuracy:0.6304
# Epoch 74, CIFAR-10 Batch 1:  Loss:0.0534 Validation_accuracy:0.6322
# Epoch 75, CIFAR-10 Batch 1:  Loss:0.0475 Validation_accuracy:0.6292
# Epoch 76, CIFAR-10 Batch 1:  Loss:0.0466 Validation_accuracy:0.6224
# Epoch 77, CIFAR-10 Batch 1:  Loss:0.0499 Validation_accuracy:0.6164
# Epoch 78, CIFAR-10 Batch 1:  Loss:0.0605 Validation_accuracy:0.6114
# Epoch 79, CIFAR-10 Batch 1:  Loss:0.0511 Validation_accuracy:0.6218
# Epoch 80, CIFAR-10 Batch 1:  Loss:0.0607 Validation_accuracy:0.6082

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:1.9919 Validation_accuracy:0.3122
# Epoch  1, CIFAR-10 Batch 2:  Loss:1.6828 Validation_accuracy:0.3534
# Epoch  1, CIFAR-10 Batch 3:  Loss:1.5118 Validation_accuracy:0.4138
# Epoch  1, CIFAR-10 Batch 4:  Loss:1.4105 Validation_accuracy:0.4516
# Epoch  1, CIFAR-10 Batch 5:  Loss:1.4291 Validation_accuracy:0.4808
# Epoch  2, CIFAR-10 Batch 1:  Loss:1.4526 Validation_accuracy:0.5008
# Epoch  2, CIFAR-10 Batch 2:  Loss:1.2875 Validation_accuracy:0.5164
# Epoch  2, CIFAR-10 Batch 3:  Loss:1.2187 Validation_accuracy:0.5118
# Epoch  2, CIFAR-10 Batch 4:  Loss:1.1541 Validation_accuracy:0.5368
# Epoch  2, CIFAR-10 Batch 5:  Loss:1.2009 Validation_accuracy:0.5524
# Epoch  3, CIFAR-10 Batch 1:  Loss:1.2609 Validation_accuracy:0.5620
# Epoch  3, CIFAR-10 Batch 2:  Loss:1.1856 Validation_accuracy:0.5514
# Epoch  3, CIFAR-10 Batch 3:  Loss:1.0766 Validation_accuracy:0.5680
# Epoch  3, CIFAR-10 Batch 4:  Loss:1.0210 Validation_accuracy:0.5836
# Epoch  3, CIFAR-10 Batch 5:  Loss:1.0705 Validation_accuracy:0.5854
# Epoch  4, CIFAR-10 Batch 1:  Loss:1.1603 Validation_accuracy:0.5830
# Epoch  4, CIFAR-10 Batch 2:  Loss:1.0719 Validation_accuracy:0.5766
# Epoch  4, CIFAR-10 Batch 3:  Loss:0.9682 Validation_accuracy:0.5784
# Epoch  4, CIFAR-10 Batch 4:  Loss:0.9355 Validation_accuracy:0.6024
# Epoch  4, CIFAR-10 Batch 5:  Loss:0.9876 Validation_accuracy:0.6036
# Epoch  5, CIFAR-10 Batch 1:  Loss:1.0822 Validation_accuracy:0.5934
# Epoch  5, CIFAR-10 Batch 2:  Loss:0.9849 Validation_accuracy:0.6038
# Epoch  5, CIFAR-10 Batch 3:  Loss:0.9100 Validation_accuracy:0.6080
# Epoch  5, CIFAR-10 Batch 4:  Loss:0.8824 Validation_accuracy:0.6274
# Epoch  5, CIFAR-10 Batch 5:  Loss:0.9170 Validation_accuracy:0.6210
# Epoch  6, CIFAR-10 Batch 1:  Loss:0.9859 Validation_accuracy:0.6224
# Epoch  6, CIFAR-10 Batch 2:  Loss:0.9532 Validation_accuracy:0.6180
# Epoch  6, CIFAR-10 Batch 3:  Loss:0.8460 Validation_accuracy:0.6126
# Epoch  6, CIFAR-10 Batch 4:  Loss:0.8542 Validation_accuracy:0.6384
# Epoch  6, CIFAR-10 Batch 5:  Loss:0.8756 Validation_accuracy:0.6322
# Epoch  7, CIFAR-10 Batch 1:  Loss:0.9311 Validation_accuracy:0.6390
# Epoch  7, CIFAR-10 Batch 2:  Loss:0.8911 Validation_accuracy:0.6248
# Epoch  7, CIFAR-10 Batch 3:  Loss:0.7839 Validation_accuracy:0.6344
# Epoch  7, CIFAR-10 Batch 4:  Loss:0.7855 Validation_accuracy:0.6500
# Epoch  7, CIFAR-10 Batch 5:  Loss:0.7975 Validation_accuracy:0.6482
# Epoch  8, CIFAR-10 Batch 1:  Loss:0.9088 Validation_accuracy:0.6486
# Epoch  8, CIFAR-10 Batch 2:  Loss:0.8114 Validation_accuracy:0.6480
# Epoch  8, CIFAR-10 Batch 3:  Loss:0.7285 Validation_accuracy:0.6444
# Epoch  8, CIFAR-10 Batch 4:  Loss:0.7523 Validation_accuracy:0.6540
# Epoch  8, CIFAR-10 Batch 5:  Loss:0.7391 Validation_accuracy:0.6610
# Epoch  9, CIFAR-10 Batch 1:  Loss:0.8453 Validation_accuracy:0.6490
# Epoch  9, CIFAR-10 Batch 2:  Loss:0.7724 Validation_accuracy:0.6492
# Epoch  9, CIFAR-10 Batch 3:  Loss:0.7199 Validation_accuracy:0.6336
# Epoch  9, CIFAR-10 Batch 4:  Loss:0.7485 Validation_accuracy:0.6554
# Epoch  9, CIFAR-10 Batch 5:  Loss:0.7067 Validation_accuracy:0.6528
# Epoch 10, CIFAR-10 Batch 1:  Loss:0.8333 Validation_accuracy:0.6596
# Epoch 10, CIFAR-10 Batch 2:  Loss:0.7810 Validation_accuracy:0.6488
# Epoch 10, CIFAR-10 Batch 3:  Loss:0.6505 Validation_accuracy:0.6596
# Epoch 10, CIFAR-10 Batch 4:  Loss:0.6893 Validation_accuracy:0.6688
# Epoch 10, CIFAR-10 Batch 5:  Loss:0.6955 Validation_accuracy:0.6690
# Epoch 11, CIFAR-10 Batch 1:  Loss:0.7779 Validation_accuracy:0.6648
# Epoch 11, CIFAR-10 Batch 2:  Loss:0.6854 Validation_accuracy:0.6668
# Epoch 11, CIFAR-10 Batch 3:  Loss:0.6375 Validation_accuracy:0.6622
# Epoch 11, CIFAR-10 Batch 4:  Loss:0.6654 Validation_accuracy:0.6762
# Epoch 11, CIFAR-10 Batch 5:  Loss:0.6502 Validation_accuracy:0.6700
# Epoch 12, CIFAR-10 Batch 1:  Loss:0.7467 Validation_accuracy:0.6670
# Epoch 12, CIFAR-10 Batch 2:  Loss:0.6903 Validation_accuracy:0.6678
# Epoch 12, CIFAR-10 Batch 3:  Loss:0.6176 Validation_accuracy:0.6642
# Epoch 12, CIFAR-10 Batch 4:  Loss:0.6329 Validation_accuracy:0.6730
# Epoch 12, CIFAR-10 Batch 5:  Loss:0.6342 Validation_accuracy:0.6792
# Epoch 13, CIFAR-10 Batch 1:  Loss:0.7105 Validation_accuracy:0.6744
# Epoch 13, CIFAR-10 Batch 2:  Loss:0.6559 Validation_accuracy:0.6794
# Epoch 13, CIFAR-10 Batch 3:  Loss:0.5899 Validation_accuracy:0.6694
# Epoch 13, CIFAR-10 Batch 4:  Loss:0.6237 Validation_accuracy:0.6738
# Epoch 13, CIFAR-10 Batch 5:  Loss:0.5689 Validation_accuracy:0.6850
# Epoch 14, CIFAR-10 Batch 1:  Loss:0.6640 Validation_accuracy:0.6816
# Epoch 14, CIFAR-10 Batch 2:  Loss:0.6392 Validation_accuracy:0.6692
# Epoch 14, CIFAR-10 Batch 3:  Loss:0.5631 Validation_accuracy:0.6726
# Epoch 14, CIFAR-10 Batch 4:  Loss:0.5866 Validation_accuracy:0.6822
# Epoch 14, CIFAR-10 Batch 5:  Loss:0.5521 Validation_accuracy:0.6914
# Epoch 15, CIFAR-10 Batch 1:  Loss:0.6376 Validation_accuracy:0.6868
# Epoch 15, CIFAR-10 Batch 2:  Loss:0.6000 Validation_accuracy:0.6848
# Epoch 15, CIFAR-10 Batch 3:  Loss:0.5301 Validation_accuracy:0.6816
# Epoch 15, CIFAR-10 Batch 4:  Loss:0.5858 Validation_accuracy:0.6774
# Epoch 15, CIFAR-10 Batch 5:  Loss:0.5108 Validation_accuracy:0.6910
# Epoch 16, CIFAR-10 Batch 1:  Loss:0.6050 Validation_accuracy:0.6856
# Epoch 16, CIFAR-10 Batch 2:  Loss:0.5877 Validation_accuracy:0.6878
# Epoch 16, CIFAR-10 Batch 3:  Loss:0.5213 Validation_accuracy:0.6750
# Epoch 16, CIFAR-10 Batch 4:  Loss:0.5636 Validation_accuracy:0.6838
# Epoch 16, CIFAR-10 Batch 5:  Loss:0.5331 Validation_accuracy:0.6848
# Epoch 17, CIFAR-10 Batch 1:  Loss:0.5821 Validation_accuracy:0.6926
# Epoch 17, CIFAR-10 Batch 2:  Loss:0.5526 Validation_accuracy:0.6898
# Epoch 17, CIFAR-10 Batch 3:  Loss:0.4947 Validation_accuracy:0.6732
# Epoch 17, CIFAR-10 Batch 4:  Loss:0.5306 Validation_accuracy:0.6902
# Epoch 17, CIFAR-10 Batch 5:  Loss:0.4943 Validation_accuracy:0.6924
# Epoch 18, CIFAR-10 Batch 1:  Loss:0.5605 Validation_accuracy:0.6944
# Epoch 18, CIFAR-10 Batch 2:  Loss:0.5258 Validation_accuracy:0.6930
# Epoch 18, CIFAR-10 Batch 3:  Loss:0.4711 Validation_accuracy:0.6784
# Epoch 18, CIFAR-10 Batch 4:  Loss:0.4881 Validation_accuracy:0.6894
# Epoch 18, CIFAR-10 Batch 5:  Loss:0.4724 Validation_accuracy:0.6946
# Epoch 19, CIFAR-10 Batch 1:  Loss:0.5412 Validation_accuracy:0.6876
# Epoch 19, CIFAR-10 Batch 2:  Loss:0.5328 Validation_accuracy:0.6896
# Epoch 19, CIFAR-10 Batch 3:  Loss:0.4640 Validation_accuracy:0.6834
# Epoch 19, CIFAR-10 Batch 4:  Loss:0.4897 Validation_accuracy:0.6926
# Epoch 19, CIFAR-10 Batch 5:  Loss:0.4636 Validation_accuracy:0.6892
# Epoch 20, CIFAR-10 Batch 1:  Loss:0.5240 Validation_accuracy:0.6914
# Epoch 20, CIFAR-10 Batch 2:  Loss:0.5177 Validation_accuracy:0.6948
# Epoch 20, CIFAR-10 Batch 3:  Loss:0.4435 Validation_accuracy:0.6830
# Epoch 20, CIFAR-10 Batch 4:  Loss:0.4711 Validation_accuracy:0.6910
# Epoch 20, CIFAR-10 Batch 5:  Loss:0.4337 Validation_accuracy:0.6962
# Epoch 21, CIFAR-10 Batch 1:  Loss:0.4976 Validation_accuracy:0.6916
# Epoch 21, CIFAR-10 Batch 2:  Loss:0.4947 Validation_accuracy:0.6908
# Epoch 21, CIFAR-10 Batch 3:  Loss:0.4167 Validation_accuracy:0.6940
# Epoch 21, CIFAR-10 Batch 4:  Loss:0.4371 Validation_accuracy:0.6960
# Epoch 21, CIFAR-10 Batch 5:  Loss:0.3860 Validation_accuracy:0.7086
# Epoch 22, CIFAR-10 Batch 1:  Loss:0.4639 Validation_accuracy:0.6980
# Epoch 22, CIFAR-10 Batch 2:  Loss:0.4632 Validation_accuracy:0.7014
# Epoch 22, CIFAR-10 Batch 3:  Loss:0.3981 Validation_accuracy:0.6934
# Epoch 22, CIFAR-10 Batch 4:  Loss:0.4194 Validation_accuracy:0.6934
# Epoch 22, CIFAR-10 Batch 5:  Loss:0.4128 Validation_accuracy:0.6948
# Epoch 23, CIFAR-10 Batch 1:  Loss:0.4724 Validation_accuracy:0.6934
# Epoch 23, CIFAR-10 Batch 2:  Loss:0.4392 Validation_accuracy:0.7000
# Epoch 23, CIFAR-10 Batch 3:  Loss:0.3671 Validation_accuracy:0.7000
# Epoch 23, CIFAR-10 Batch 4:  Loss:0.3893 Validation_accuracy:0.6992
# Epoch 23, CIFAR-10 Batch 5:  Loss:0.3683 Validation_accuracy:0.7044
# Epoch 24, CIFAR-10 Batch 1:  Loss:0.4491 Validation_accuracy:0.6948
# Epoch 24, CIFAR-10 Batch 2:  Loss:0.4187 Validation_accuracy:0.6952
# Epoch 24, CIFAR-10 Batch 3:  Loss:0.3344 Validation_accuracy:0.6960
# Epoch 24, CIFAR-10 Batch 4:  Loss:0.3817 Validation_accuracy:0.7026
# Epoch 24, CIFAR-10 Batch 5:  Loss:0.3542 Validation_accuracy:0.7046
# Epoch 25, CIFAR-10 Batch 1:  Loss:0.4289 Validation_accuracy:0.6962
# Epoch 25, CIFAR-10 Batch 2:  Loss:0.4209 Validation_accuracy:0.6984
# Epoch 25, CIFAR-10 Batch 3:  Loss:0.3488 Validation_accuracy:0.7020
# Epoch 25, CIFAR-10 Batch 4:  Loss:0.3733 Validation_accuracy:0.7000
# Epoch 25, CIFAR-10 Batch 5:  Loss:0.3441 Validation_accuracy:0.6998
# Epoch 26, CIFAR-10 Batch 1:  Loss:0.4232 Validation_accuracy:0.6914
# Epoch 26, CIFAR-10 Batch 2:  Loss:0.3842 Validation_accuracy:0.7018
# Epoch 26, CIFAR-10 Batch 3:  Loss:0.3322 Validation_accuracy:0.7032
# Epoch 26, CIFAR-10 Batch 4:  Loss:0.3659 Validation_accuracy:0.6968
# Epoch 26, CIFAR-10 Batch 5:  Loss:0.3166 Validation_accuracy:0.7044
# Epoch 27, CIFAR-10 Batch 1:  Loss:0.3985 Validation_accuracy:0.7024
# Epoch 27, CIFAR-10 Batch 2:  Loss:0.3672 Validation_accuracy:0.7004
# Epoch 27, CIFAR-10 Batch 3:  Loss:0.3215 Validation_accuracy:0.7032
# Epoch 27, CIFAR-10 Batch 4:  Loss:0.3348 Validation_accuracy:0.7060
# Epoch 27, CIFAR-10 Batch 5:  Loss:0.3143 Validation_accuracy:0.7080
# Epoch 28, CIFAR-10 Batch 1:  Loss:0.3686 Validation_accuracy:0.6984
# Epoch 28, CIFAR-10 Batch 2:  Loss:0.3541 Validation_accuracy:0.7042
# Epoch 28, CIFAR-10 Batch 3:  Loss:0.3041 Validation_accuracy:0.7054
# Epoch 28, CIFAR-10 Batch 4:  Loss:0.3321 Validation_accuracy:0.7016
# Epoch 28, CIFAR-10 Batch 5:  Loss:0.3031 Validation_accuracy:0.6970
# Epoch 29, CIFAR-10 Batch 1:  Loss:0.3416 Validation_accuracy:0.7046
# Epoch 29, CIFAR-10 Batch 2:  Loss:0.3349 Validation_accuracy:0.7048
# Epoch 29, CIFAR-10 Batch 3:  Loss:0.2986 Validation_accuracy:0.6954
# Epoch 29, CIFAR-10 Batch 4:  Loss:0.3303 Validation_accuracy:0.6970
# Epoch 29, CIFAR-10 Batch 5:  Loss:0.3125 Validation_accuracy:0.6960
# Epoch 30, CIFAR-10 Batch 1:  Loss:0.3433 Validation_accuracy:0.6918
# Epoch 30, CIFAR-10 Batch 2:  Loss:0.3306 Validation_accuracy:0.6994
# Epoch 30, CIFAR-10 Batch 3:  Loss:0.2863 Validation_accuracy:0.6984
# Epoch 30, CIFAR-10 Batch 4:  Loss:0.3245 Validation_accuracy:0.7008
# Epoch 30, CIFAR-10 Batch 5:  Loss:0.2865 Validation_accuracy:0.7026
# Epoch 31, CIFAR-10 Batch 1:  Loss:0.3203 Validation_accuracy:0.7018
# Epoch 31, CIFAR-10 Batch 2:  Loss:0.3408 Validation_accuracy:0.7088
# Epoch 31, CIFAR-10 Batch 3:  Loss:0.3021 Validation_accuracy:0.6946
# Epoch 31, CIFAR-10 Batch 4:  Loss:0.3168 Validation_accuracy:0.7030
# Epoch 31, CIFAR-10 Batch 5:  Loss:0.2713 Validation_accuracy:0.7018
# Epoch 32, CIFAR-10 Batch 1:  Loss:0.3409 Validation_accuracy:0.6906
# Epoch 32, CIFAR-10 Batch 2:  Loss:0.3346 Validation_accuracy:0.6998
# Epoch 32, CIFAR-10 Batch 3:  Loss:0.2719 Validation_accuracy:0.6990
# Epoch 32, CIFAR-10 Batch 4:  Loss:0.2866 Validation_accuracy:0.7036
# Epoch 32, CIFAR-10 Batch 5:  Loss:0.2702 Validation_accuracy:0.6994
# Epoch 33, CIFAR-10 Batch 1:  Loss:0.3323 Validation_accuracy:0.6908
# Epoch 33, CIFAR-10 Batch 2:  Loss:0.2987 Validation_accuracy:0.7046
# Epoch 33, CIFAR-10 Batch 3:  Loss:0.2841 Validation_accuracy:0.6974
# Epoch 33, CIFAR-10 Batch 4:  Loss:0.3095 Validation_accuracy:0.6958
# Epoch 33, CIFAR-10 Batch 5:  Loss:0.2574 Validation_accuracy:0.6994
# Epoch 34, CIFAR-10 Batch 1:  Loss:0.3151 Validation_accuracy:0.6944
# Epoch 34, CIFAR-10 Batch 2:  Loss:0.3034 Validation_accuracy:0.7022
# Epoch 34, CIFAR-10 Batch 3:  Loss:0.2637 Validation_accuracy:0.7014
# Epoch 34, CIFAR-10 Batch 4:  Loss:0.2921 Validation_accuracy:0.6936
# Epoch 34, CIFAR-10 Batch 5:  Loss:0.2613 Validation_accuracy:0.6952
# Epoch 35, CIFAR-10 Batch 1:  Loss:0.2768 Validation_accuracy:0.6932
# Epoch 35, CIFAR-10 Batch 2:  Loss:0.2948 Validation_accuracy:0.6958
# Epoch 35, CIFAR-10 Batch 3:  Loss:0.2757 Validation_accuracy:0.6910
# Epoch 35, CIFAR-10 Batch 4:  Loss:0.3017 Validation_accuracy:0.6922
# Epoch 35, CIFAR-10 Batch 5:  Loss:0.2980 Validation_accuracy:0.6838
# Epoch 36, CIFAR-10 Batch 1:  Loss:0.2598 Validation_accuracy:0.7058
# Epoch 36, CIFAR-10 Batch 2:  Loss:0.3010 Validation_accuracy:0.7000
# Epoch 36, CIFAR-10 Batch 3:  Loss:0.2498 Validation_accuracy:0.6980
# Epoch 36, CIFAR-10 Batch 4:  Loss:0.2970 Validation_accuracy:0.6916
# Epoch 36, CIFAR-10 Batch 5:  Loss:0.2699 Validation_accuracy:0.7010
# Epoch 37, CIFAR-10 Batch 1:  Loss:0.2515 Validation_accuracy:0.7076
# Epoch 37, CIFAR-10 Batch 2:  Loss:0.2718 Validation_accuracy:0.7058
# Epoch 37, CIFAR-10 Batch 3:  Loss:0.2404 Validation_accuracy:0.6964
# Epoch 37, CIFAR-10 Batch 4:  Loss:0.2888 Validation_accuracy:0.6878
# Epoch 37, CIFAR-10 Batch 5:  Loss:0.2250 Validation_accuracy:0.6978
# Epoch 38, CIFAR-10 Batch 1:  Loss:0.2418 Validation_accuracy:0.7110
# Epoch 38, CIFAR-10 Batch 2:  Loss:0.2684 Validation_accuracy:0.7056
# Epoch 38, CIFAR-10 Batch 3:  Loss:0.2314 Validation_accuracy:0.6994
# Epoch 38, CIFAR-10 Batch 4:  Loss:0.2360 Validation_accuracy:0.6972
# Epoch 38, CIFAR-10 Batch 5:  Loss:0.2268 Validation_accuracy:0.7022
# Epoch 39, CIFAR-10 Batch 1:  Loss:0.2508 Validation_accuracy:0.7116
# Epoch 39, CIFAR-10 Batch 2:  Loss:0.2508 Validation_accuracy:0.7050
# Epoch 39, CIFAR-10 Batch 3:  Loss:0.2376 Validation_accuracy:0.6994
# Epoch 39, CIFAR-10 Batch 4:  Loss:0.2440 Validation_accuracy:0.7010
# Epoch 39, CIFAR-10 Batch 5:  Loss:0.2242 Validation_accuracy:0.7012
# Epoch 40, CIFAR-10 Batch 1:  Loss:0.2226 Validation_accuracy:0.7096
# Epoch 40, CIFAR-10 Batch 2:  Loss:0.2443 Validation_accuracy:0.7060
# Epoch 40, CIFAR-10 Batch 3:  Loss:0.2097 Validation_accuracy:0.7044
# Epoch 40, CIFAR-10 Batch 4:  Loss:0.2186 Validation_accuracy:0.6894
# Epoch 40, CIFAR-10 Batch 5:  Loss:0.2447 Validation_accuracy:0.6840
# Epoch 41, CIFAR-10 Batch 1:  Loss:0.2339 Validation_accuracy:0.7044
# Epoch 41, CIFAR-10 Batch 2:  Loss:0.2179 Validation_accuracy:0.7076
# Epoch 41, CIFAR-10 Batch 3:  Loss:0.1923 Validation_accuracy:0.7054
# Epoch 41, CIFAR-10 Batch 4:  Loss:0.2447 Validation_accuracy:0.6924
# Epoch 41, CIFAR-10 Batch 5:  Loss:0.1914 Validation_accuracy:0.7042
# Epoch 42, CIFAR-10 Batch 1:  Loss:0.2200 Validation_accuracy:0.7080
# Epoch 42, CIFAR-10 Batch 2:  Loss:0.2343 Validation_accuracy:0.7106
# Epoch 42, CIFAR-10 Batch 3:  Loss:0.1880 Validation_accuracy:0.7058
# Epoch 42, CIFAR-10 Batch 4:  Loss:0.2158 Validation_accuracy:0.7060
# Epoch 42, CIFAR-10 Batch 5:  Loss:0.2041 Validation_accuracy:0.6956
# Epoch 43, CIFAR-10 Batch 1:  Loss:0.2214 Validation_accuracy:0.7074
# Epoch 43, CIFAR-10 Batch 2:  Loss:0.2116 Validation_accuracy:0.7100
# Epoch 43, CIFAR-10 Batch 3:  Loss:0.1835 Validation_accuracy:0.7136
# Epoch 43, CIFAR-10 Batch 4:  Loss:0.2063 Validation_accuracy:0.7004
# Epoch 43, CIFAR-10 Batch 5:  Loss:0.1923 Validation_accuracy:0.6982
# Epoch 44, CIFAR-10 Batch 1:  Loss:0.1844 Validation_accuracy:0.7136
# Epoch 44, CIFAR-10 Batch 2:  Loss:0.2170 Validation_accuracy:0.7032
# Epoch 44, CIFAR-10 Batch 3:  Loss:0.1711 Validation_accuracy:0.7144
# Epoch 44, CIFAR-10 Batch 4:  Loss:0.2313 Validation_accuracy:0.6930
# Epoch 44, CIFAR-10 Batch 5:  Loss:0.2125 Validation_accuracy:0.6904
# Epoch 45, CIFAR-10 Batch 1:  Loss:0.1920 Validation_accuracy:0.7098
# Epoch 45, CIFAR-10 Batch 2:  Loss:0.2034 Validation_accuracy:0.7038
# Epoch 45, CIFAR-10 Batch 3:  Loss:0.1664 Validation_accuracy:0.7092
# Epoch 45, CIFAR-10 Batch 4:  Loss:0.2164 Validation_accuracy:0.7052
# Epoch 45, CIFAR-10 Batch 5:  Loss:0.1668 Validation_accuracy:0.6984
# Epoch 46, CIFAR-10 Batch 1:  Loss:0.1885 Validation_accuracy:0.7074
# Epoch 46, CIFAR-10 Batch 2:  Loss:0.1907 Validation_accuracy:0.7060
# Epoch 46, CIFAR-10 Batch 3:  Loss:0.1495 Validation_accuracy:0.7106
# Epoch 46, CIFAR-10 Batch 4:  Loss:0.1895 Validation_accuracy:0.7118
# Epoch 46, CIFAR-10 Batch 5:  Loss:0.1578 Validation_accuracy:0.7024
# Epoch 47, CIFAR-10 Batch 1:  Loss:0.1775 Validation_accuracy:0.7110
# Epoch 47, CIFAR-10 Batch 2:  Loss:0.2019 Validation_accuracy:0.7042
# Epoch 47, CIFAR-10 Batch 3:  Loss:0.1466 Validation_accuracy:0.7066
# Epoch 47, CIFAR-10 Batch 4:  Loss:0.1790 Validation_accuracy:0.7036
# Epoch 47, CIFAR-10 Batch 5:  Loss:0.1744 Validation_accuracy:0.7054
# Epoch 48, CIFAR-10 Batch 1:  Loss:0.1785 Validation_accuracy:0.7074
# Epoch 48, CIFAR-10 Batch 2:  Loss:0.1886 Validation_accuracy:0.7078
# Epoch 48, CIFAR-10 Batch 3:  Loss:0.1373 Validation_accuracy:0.7072
# Epoch 48, CIFAR-10 Batch 4:  Loss:0.1680 Validation_accuracy:0.7112
# Epoch 48, CIFAR-10 Batch 5:  Loss:0.1541 Validation_accuracy:0.7014
# Epoch 49, CIFAR-10 Batch 1:  Loss:0.1871 Validation_accuracy:0.6990
# Epoch 49, CIFAR-10 Batch 2:  Loss:0.1913 Validation_accuracy:0.6966
# Epoch 49, CIFAR-10 Batch 3:  Loss:0.1423 Validation_accuracy:0.7056
# Epoch 49, CIFAR-10 Batch 4:  Loss:0.1600 Validation_accuracy:0.7138
# Epoch 49, CIFAR-10 Batch 5:  Loss:0.1391 Validation_accuracy:0.7032
# Epoch 50, CIFAR-10 Batch 1:  Loss:0.1547 Validation_accuracy:0.7112
# Epoch 50, CIFAR-10 Batch 2:  Loss:0.1969 Validation_accuracy:0.6924
# Epoch 50, CIFAR-10 Batch 3:  Loss:0.1348 Validation_accuracy:0.6988
# Epoch 50, CIFAR-10 Batch 4:  Loss:0.1581 Validation_accuracy:0.7092
# Epoch 50, CIFAR-10 Batch 5:  Loss:0.1297 Validation_accuracy:0.6978
# Epoch 51, CIFAR-10 Batch 1:  Loss:0.1283 Validation_accuracy:0.7118
# Epoch 51, CIFAR-10 Batch 2:  Loss:0.1737 Validation_accuracy:0.7072
# Epoch 51, CIFAR-10 Batch 3:  Loss:0.1265 Validation_accuracy:0.7084
# Epoch 51, CIFAR-10 Batch 4:  Loss:0.1543 Validation_accuracy:0.7150
# Epoch 51, CIFAR-10 Batch 5:  Loss:0.1182 Validation_accuracy:0.7044
# Epoch 52, CIFAR-10 Batch 1:  Loss:0.1191 Validation_accuracy:0.7066
# Epoch 52, CIFAR-10 Batch 2:  Loss:0.1759 Validation_accuracy:0.6958
# Epoch 52, CIFAR-10 Batch 3:  Loss:0.1374 Validation_accuracy:0.6986
# Epoch 52, CIFAR-10 Batch 4:  Loss:0.1463 Validation_accuracy:0.7142
# Epoch 52, CIFAR-10 Batch 5:  Loss:0.1249 Validation_accuracy:0.7088
# Epoch 53, CIFAR-10 Batch 1:  Loss:0.1456 Validation_accuracy:0.7048
# Epoch 53, CIFAR-10 Batch 2:  Loss:0.1817 Validation_accuracy:0.7012
# Epoch 53, CIFAR-10 Batch 3:  Loss:0.1433 Validation_accuracy:0.6972
# Epoch 53, CIFAR-10 Batch 4:  Loss:0.1498 Validation_accuracy:0.7090
# Epoch 53, CIFAR-10 Batch 5:  Loss:0.1270 Validation_accuracy:0.6964
# Epoch 54, CIFAR-10 Batch 1:  Loss:0.1544 Validation_accuracy:0.7018
# Epoch 54, CIFAR-10 Batch 2:  Loss:0.1508 Validation_accuracy:0.7022
# Epoch 54, CIFAR-10 Batch 3:  Loss:0.1230 Validation_accuracy:0.7038
# Epoch 54, CIFAR-10 Batch 4:  Loss:0.1335 Validation_accuracy:0.7078
# Epoch 54, CIFAR-10 Batch 5:  Loss:0.1041 Validation_accuracy:0.7016
# Epoch 55, CIFAR-10 Batch 1:  Loss:0.1146 Validation_accuracy:0.7130
# Epoch 55, CIFAR-10 Batch 2:  Loss:0.1391 Validation_accuracy:0.7076
# Epoch 55, CIFAR-10 Batch 3:  Loss:0.1185 Validation_accuracy:0.6978
# Epoch 55, CIFAR-10 Batch 4:  Loss:0.1387 Validation_accuracy:0.7114
# Epoch 55, CIFAR-10 Batch 5:  Loss:0.0976 Validation_accuracy:0.7084
# Epoch 56, CIFAR-10 Batch 1:  Loss:0.1208 Validation_accuracy:0.7060
# Epoch 56, CIFAR-10 Batch 2:  Loss:0.1290 Validation_accuracy:0.6904
# Epoch 56, CIFAR-10 Batch 3:  Loss:0.1355 Validation_accuracy:0.7014
# Epoch 56, CIFAR-10 Batch 4:  Loss:0.1374 Validation_accuracy:0.7030
# Epoch 56, CIFAR-10 Batch 5:  Loss:0.0861 Validation_accuracy:0.7004
# Epoch 57, CIFAR-10 Batch 1:  Loss:0.1044 Validation_accuracy:0.7048
# Epoch 57, CIFAR-10 Batch 2:  Loss:0.1316 Validation_accuracy:0.7016
# Epoch 57, CIFAR-10 Batch 3:  Loss:0.1182 Validation_accuracy:0.6998
# Epoch 57, CIFAR-10 Batch 4:  Loss:0.1122 Validation_accuracy:0.7046
# Epoch 57, CIFAR-10 Batch 5:  Loss:0.1127 Validation_accuracy:0.6902
# Epoch 58, CIFAR-10 Batch 1:  Loss:0.1082 Validation_accuracy:0.7036
# Epoch 58, CIFAR-10 Batch 2:  Loss:0.1347 Validation_accuracy:0.6974
# Epoch 58, CIFAR-10 Batch 3:  Loss:0.1093 Validation_accuracy:0.7096
# Epoch 58, CIFAR-10 Batch 4:  Loss:0.1241 Validation_accuracy:0.6992
# Epoch 58, CIFAR-10 Batch 5:  Loss:0.1082 Validation_accuracy:0.7032
# Epoch 59, CIFAR-10 Batch 1:  Loss:0.1233 Validation_accuracy:0.7020
# Epoch 59, CIFAR-10 Batch 2:  Loss:0.1449 Validation_accuracy:0.6976
# Epoch 59, CIFAR-10 Batch 3:  Loss:0.1008 Validation_accuracy:0.7004
# Epoch 59, CIFAR-10 Batch 4:  Loss:0.1074 Validation_accuracy:0.7028
# Epoch 59, CIFAR-10 Batch 5:  Loss:0.0913 Validation_accuracy:0.7002
# Epoch 60, CIFAR-10 Batch 1:  Loss:0.0905 Validation_accuracy:0.7028
# Epoch 60, CIFAR-10 Batch 2:  Loss:0.1240 Validation_accuracy:0.7020
# Epoch 60, CIFAR-10 Batch 3:  Loss:0.0959 Validation_accuracy:0.7040
# Epoch 60, CIFAR-10 Batch 4:  Loss:0.1121 Validation_accuracy:0.6978
# Epoch 60, CIFAR-10 Batch 5:  Loss:0.0743 Validation_accuracy:0.7040
# Epoch 61, CIFAR-10 Batch 1:  Loss:0.0858 Validation_accuracy:0.7120
# Epoch 61, CIFAR-10 Batch 2:  Loss:0.1153 Validation_accuracy:0.7008
# Epoch 61, CIFAR-10 Batch 3:  Loss:0.0921 Validation_accuracy:0.6984
# Epoch 61, CIFAR-10 Batch 4:  Loss:0.0988 Validation_accuracy:0.7028
# Epoch 61, CIFAR-10 Batch 5:  Loss:0.0785 Validation_accuracy:0.7040
# Epoch 62, CIFAR-10 Batch 1:  Loss:0.0850 Validation_accuracy:0.7002
# Epoch 62, CIFAR-10 Batch 2:  Loss:0.1215 Validation_accuracy:0.6916
# Epoch 62, CIFAR-10 Batch 3:  Loss:0.0849 Validation_accuracy:0.6966
# Epoch 62, CIFAR-10 Batch 4:  Loss:0.1021 Validation_accuracy:0.6958
# Epoch 62, CIFAR-10 Batch 5:  Loss:0.0866 Validation_accuracy:0.6974
# Epoch 63, CIFAR-10 Batch 1:  Loss:0.0791 Validation_accuracy:0.7036
# Epoch 63, CIFAR-10 Batch 2:  Loss:0.1162 Validation_accuracy:0.6978
# Epoch 63, CIFAR-10 Batch 3:  Loss:0.1056 Validation_accuracy:0.6928
# Epoch 63, CIFAR-10 Batch 4:  Loss:0.1128 Validation_accuracy:0.6976
# Epoch 63, CIFAR-10 Batch 5:  Loss:0.0937 Validation_accuracy:0.7016
# Epoch 64, CIFAR-10 Batch 1:  Loss:0.0778 Validation_accuracy:0.7006
# Epoch 64, CIFAR-10 Batch 2:  Loss:0.1107 Validation_accuracy:0.6980
# Epoch 64, CIFAR-10 Batch 3:  Loss:0.0874 Validation_accuracy:0.6942
# Epoch 64, CIFAR-10 Batch 4:  Loss:0.1003 Validation_accuracy:0.6974
# Epoch 64, CIFAR-10 Batch 5:  Loss:0.0884 Validation_accuracy:0.6968
# Epoch 65, CIFAR-10 Batch 1:  Loss:0.0741 Validation_accuracy:0.7022
# Epoch 65, CIFAR-10 Batch 2:  Loss:0.1217 Validation_accuracy:0.6840
# Epoch 65, CIFAR-10 Batch 3:  Loss:0.0779 Validation_accuracy:0.7000
# Epoch 65, CIFAR-10 Batch 4:  Loss:0.1121 Validation_accuracy:0.6980
# Epoch 65, CIFAR-10 Batch 5:  Loss:0.0931 Validation_accuracy:0.6952
# Epoch 66, CIFAR-10 Batch 1:  Loss:0.0887 Validation_accuracy:0.7000
# Epoch 66, CIFAR-10 Batch 2:  Loss:0.0992 Validation_accuracy:0.6994
# Epoch 66, CIFAR-10 Batch 3:  Loss:0.0868 Validation_accuracy:0.7020
# Epoch 66, CIFAR-10 Batch 4:  Loss:0.1103 Validation_accuracy:0.6954
# Epoch 66, CIFAR-10 Batch 5:  Loss:0.1047 Validation_accuracy:0.6964
# Epoch 67, CIFAR-10 Batch 1:  Loss:0.0801 Validation_accuracy:0.7064
# Epoch 67, CIFAR-10 Batch 2:  Loss:0.0883 Validation_accuracy:0.7042
# Epoch 67, CIFAR-10 Batch 3:  Loss:0.0786 Validation_accuracy:0.6944
# Epoch 67, CIFAR-10 Batch 4:  Loss:0.1227 Validation_accuracy:0.6882
# Epoch 67, CIFAR-10 Batch 5:  Loss:0.1017 Validation_accuracy:0.6958
# Epoch 68, CIFAR-10 Batch 1:  Loss:0.0773 Validation_accuracy:0.7010
# Epoch 68, CIFAR-10 Batch 2:  Loss:0.0854 Validation_accuracy:0.7008
# Epoch 68, CIFAR-10 Batch 3:  Loss:0.0730 Validation_accuracy:0.7082
# Epoch 68, CIFAR-10 Batch 4:  Loss:0.1024 Validation_accuracy:0.6952
# Epoch 68, CIFAR-10 Batch 5:  Loss:0.0883 Validation_accuracy:0.6996
# Epoch 69, CIFAR-10 Batch 1:  Loss:0.0924 Validation_accuracy:0.6966
# Epoch 69, CIFAR-10 Batch 2:  Loss:0.0840 Validation_accuracy:0.6950
# Epoch 69, CIFAR-10 Batch 3:  Loss:0.0680 Validation_accuracy:0.6972
# Epoch 69, CIFAR-10 Batch 4:  Loss:0.0917 Validation_accuracy:0.6990
# Epoch 69, CIFAR-10 Batch 5:  Loss:0.0835 Validation_accuracy:0.7000
# Epoch 70, CIFAR-10 Batch 1:  Loss:0.0664 Validation_accuracy:0.7054
# Epoch 70, CIFAR-10 Batch 2:  Loss:0.0720 Validation_accuracy:0.7008
# Epoch 70, CIFAR-10 Batch 3:  Loss:0.0778 Validation_accuracy:0.7034
# Epoch 70, CIFAR-10 Batch 4:  Loss:0.0826 Validation_accuracy:0.7006
# Epoch 70, CIFAR-10 Batch 5:  Loss:0.0798 Validation_accuracy:0.6962
# Epoch 71, CIFAR-10 Batch 1:  Loss:0.0740 Validation_accuracy:0.7036
# Epoch 71, CIFAR-10 Batch 2:  Loss:0.0671 Validation_accuracy:0.6958
# Epoch 71, CIFAR-10 Batch 3:  Loss:0.0675 Validation_accuracy:0.7040
# Epoch 71, CIFAR-10 Batch 4:  Loss:0.0763 Validation_accuracy:0.7040
# Epoch 71, CIFAR-10 Batch 5:  Loss:0.0620 Validation_accuracy:0.7042
# Epoch 72, CIFAR-10 Batch 1:  Loss:0.0746 Validation_accuracy:0.7020
# Epoch 72, CIFAR-10 Batch 2:  Loss:0.0829 Validation_accuracy:0.6910
# Epoch 72, CIFAR-10 Batch 3:  Loss:0.0621 Validation_accuracy:0.7020
# Epoch 72, CIFAR-10 Batch 4:  Loss:0.0913 Validation_accuracy:0.6926
# Epoch 72, CIFAR-10 Batch 5:  Loss:0.0742 Validation_accuracy:0.6964
# Epoch 73, CIFAR-10 Batch 1:  Loss:0.0800 Validation_accuracy:0.6976
# Epoch 73, CIFAR-10 Batch 2:  Loss:0.0737 Validation_accuracy:0.6998
# Epoch 73, CIFAR-10 Batch 3:  Loss:0.0676 Validation_accuracy:0.6956
# Epoch 73, CIFAR-10 Batch 4:  Loss:0.0724 Validation_accuracy:0.6990
# Epoch 73, CIFAR-10 Batch 5:  Loss:0.0740 Validation_accuracy:0.7006
# Epoch 74, CIFAR-10 Batch 1:  Loss:0.0748 Validation_accuracy:0.6990
# Epoch 74, CIFAR-10 Batch 2:  Loss:0.0662 Validation_accuracy:0.7006
# Epoch 74, CIFAR-10 Batch 3:  Loss:0.0703 Validation_accuracy:0.7000
# Epoch 74, CIFAR-10 Batch 4:  Loss:0.0611 Validation_accuracy:0.7066
# Epoch 74, CIFAR-10 Batch 5:  Loss:0.0722 Validation_accuracy:0.6958
# Epoch 75, CIFAR-10 Batch 1:  Loss:0.0637 Validation_accuracy:0.6962
# Epoch 75, CIFAR-10 Batch 2:  Loss:0.0624 Validation_accuracy:0.6978
# Epoch 75, CIFAR-10 Batch 3:  Loss:0.0595 Validation_accuracy:0.7004
# Epoch 75, CIFAR-10 Batch 4:  Loss:0.0574 Validation_accuracy:0.7030
# Epoch 75, CIFAR-10 Batch 5:  Loss:0.0534 Validation_accuracy:0.6930
# Epoch 76, CIFAR-10 Batch 1:  Loss:0.0518 Validation_accuracy:0.6976
# Epoch 76, CIFAR-10 Batch 2:  Loss:0.0498 Validation_accuracy:0.6966
# Epoch 76, CIFAR-10 Batch 3:  Loss:0.0677 Validation_accuracy:0.6952
# Epoch 76, CIFAR-10 Batch 4:  Loss:0.0465 Validation_accuracy:0.7050
# Epoch 76, CIFAR-10 Batch 5:  Loss:0.0475 Validation_accuracy:0.7014
# Epoch 77, CIFAR-10 Batch 1:  Loss:0.0687 Validation_accuracy:0.6958
# Epoch 77, CIFAR-10 Batch 2:  Loss:0.0520 Validation_accuracy:0.6954
# Epoch 77, CIFAR-10 Batch 3:  Loss:0.0561 Validation_accuracy:0.6998
# Epoch 77, CIFAR-10 Batch 4:  Loss:0.0518 Validation_accuracy:0.7090
# Epoch 77, CIFAR-10 Batch 5:  Loss:0.0515 Validation_accuracy:0.6988
# Epoch 78, CIFAR-10 Batch 1:  Loss:0.0575 Validation_accuracy:0.6930
# Epoch 78, CIFAR-10 Batch 2:  Loss:0.0538 Validation_accuracy:0.6992
# Epoch 78, CIFAR-10 Batch 3:  Loss:0.0551 Validation_accuracy:0.6928
# Epoch 78, CIFAR-10 Batch 4:  Loss:0.0585 Validation_accuracy:0.7030
# Epoch 78, CIFAR-10 Batch 5:  Loss:0.0533 Validation_accuracy:0.7006
# Epoch 79, CIFAR-10 Batch 1:  Loss:0.0517 Validation_accuracy:0.7008
# Epoch 79, CIFAR-10 Batch 2:  Loss:0.0560 Validation_accuracy:0.6978
# Epoch 79, CIFAR-10 Batch 3:  Loss:0.0504 Validation_accuracy:0.6930
# Epoch 79, CIFAR-10 Batch 4:  Loss:0.0544 Validation_accuracy:0.7000
# Epoch 79, CIFAR-10 Batch 5:  Loss:0.0677 Validation_accuracy:0.7014
# Epoch 80, CIFAR-10 Batch 1:  Loss:0.0638 Validation_accuracy:0.7022
# Epoch 80, CIFAR-10 Batch 2:  Loss:0.0447 Validation_accuracy:0.7000
# Epoch 80, CIFAR-10 Batch 3:  Loss:0.0508 Validation_accuracy:0.7008
# Epoch 80, CIFAR-10 Batch 4:  Loss:0.0542 Validation_accuracy:0.6948
# Epoch 80, CIFAR-10 Batch 5:  Loss:0.0639 Validation_accuracy:0.6908

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6941578596830368

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
